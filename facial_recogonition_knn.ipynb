# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import sklearn
from sklearn.neighbors import KNeighborsClassifier as KNN
# %matplotlib inline 
import datetime as dt

# %%
num=1
string =repr(num)
print 's'+string
img=plt.imread('1.pgm')
print img.shape
# Out:
# s1
# (112, 92)

# %%
imag_list=[]
label=[]
for ix in range (1,21):
    string=repr(ix)
    for iy in range (1,8):
        s=repr(iy)
        address='./orl_faces/s'+string+'/'+s+'.pgm'
        img=plt.imread(address)
        img= img.reshape(112*92,)
        imag_list.append(img)
        label.append(ix)

# %%
imag_array=np.asarray(imag_list)
print imag_array.shape
# Out:
# (140, 10304)

# %%
plt.imshow(imag_array[0,:].reshape(112,92),cmap='gray')

# %%
plt.imshow(imag_array[1,:].reshape(112,92),cmap='gray')

# %%
lab=np.asarray(label)
lab= lab.reshape(140,1)

# %%
test_list=[]
test_label=[]
for ix in range (1,21):
    string=repr(ix)
    for iy in range (8,11):
        s=repr(iy)
        address='./orl_faces/s'+string+'/'+s+'.pgm'
        img=plt.imread(address)
        img= img.reshape(112*92,)
        test_list.append(img)
        test_label.append(ix)
test_array=np.asarray(test_list)
test_lab=np.asarray(test_label)
print test_array.shape,test_lab.shape
test_lab= test_lab.reshape(60,1)
# Out:
# (60, 10304) (60,)

# %%
knn=KNN(3)
knn.fit(imag_array,lab)
start=dt.datetime.now()
print knn.score(test_array,test_lab)
end=dt.datetime.now()
print end-start
# Out:
# 0.916666666667
# 0:00:00.169464
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   from ipykernel import kernelapp as app
